# %% [markdown]
# <a href="https://colab.research.google.com/github/indranildchandra/adk-crash-course-codelab/blob/main/ADK_Learning_tool_multi_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Welcome to Your ADK Adventure - MultiAgents! 🚀
#
# Welcome back, Agent Architect! This notebook dives into the heart of the Google Agent Development Kit (ADK): orchestrating teams of specialized agents to tackle complex, multi-step problems that a single agent cannot handle alone.
#
# By the end of this session, you will be an expert in advanced agentic workflows:
#
# - **SequentialAgent**: You'll learn to chain agents together, creating pipelines where the output of one agent becomes the input for the next.
#
# - **LoopAgent**: You'll build iterative systems where agents can plan, critique, and refine their work until a specific goal is met, making them "perfectionists."
#
# - **ParallelAgent**: You'll unleash efficiency by running multiple agents simultaneously and then synthesizing their collective findings into a single, comprehensive answer.
#
# - **The Router**: You will construct a "master" router agent that intelligently analyzes a user's request and delegates it to the correct agent or workflow.
#
# Let's get this adventure started!

# %% [markdown]
# -------------
# ### 🛑 Important Prerequisite: Setup Your Environment! 🛑
# -----------------------------------------------------------------------------
#
# 👉 **Get Your API Key HERE**: https://codelabs.developers.google.com/onramp/instructions#1
#
# Navigate to https://console.cloud.google.com and follow the instructions
#
#  -----------------------------------------------------------------------------

# %% [markdown]
# ```
#  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️  ⬆️
#    /\_/\     /\_/\     /\_/\      /\_/\       /\_/\
#   ( ^_^ )   ( -.- )   ( >_< )   ( =^.^= )    ( o_o )
# ```

# %% [markdown]
# ## Part 0: Setup & Authentication 🔑
#
# First things first, let's get all our tools ready. This step installs the necessary libraries and securely configures your Google API key so your agents can access the power of Gemini.

# %%
# !pip install google-adk google-generativeai -q

# --- Import all necessary libraries ---
import os
import sys
import json
import asyncio
import random
import string
from uuid import uuid4

import vertexai
from google.colab import auth
from IPython.display import HTML, Markdown, display

# --- ADK, Agent, and Evaluation Components ---
from google.adk.agents import Agent, SequentialAgent, LoopAgent, ParallelAgent
from google.adk.events import Event
from google.adk.runners import Runner
import google.adk as adk
from google.adk.tools import google_search, ToolContext
from google.adk.sessions import InMemorySessionService, Session
from google.genai import types
from google.genai.types import Content, Part

print("✅ All libraries are ready to go!")
# Out:
# ✅ All libraries are ready to go!

# %% [markdown]
# ### Authenticate and Configure Your Project
# To use Vertex AI, you need an active Google Cloud project. This section handles authenticating your environment and setting up the necessary project configurations.

# %%
# ---  Authentication & Project Configuration ---

# Authenticate user in Colab
if "google.colab" in sys.modules:
    auth.authenticate_user()
    print("✅ Authenticated successfully.")
# Out:
# ✅ Authenticated successfully.

# %%
# @title Set Your Google Cloud Project Details
PROJECT_ID = "adk-crash-course-test-496108"              # @param {type:"string"}
LOCATION = "us-central1"               # @param {type:"string"}

# Set environment variables for the ADK and gcloud
os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID
os.environ["GOOGLE_CLOUD_LOCATION"] = LOCATION
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "True"

# !gcloud services enable aiplatform.googleapis.com --project={PROJECT_ID}

print(f"\n✅ Vertex AI configured for project '{PROJECT_ID}' in '{LOCATION}'.")
# Out:
# ✅ Vertex AI configured for project 'adk-crash-course-test-496108' in 'us-central1'.

# %%
# --- A Helper Function to Run Our Agents ---
# We'll use this function throughout the notebook to make running queries easy.

async def run_agent_query(agent: Agent, query: str, session: Session, user_id: str, is_router: bool = False):
    """Initializes a runner and executes a query for a given agent and session."""
    print(f"\n🚀 Running query for agent: '{agent.name}' in session: '{session.id}'...")

    runner = Runner(
        agent=agent,
        session_service=session_service,
        app_name=agent.name
    )

    final_response = ""
    try:
        async for event in runner.run_async(
            user_id=user_id,
            session_id=session.id,
            new_message=Content(parts=[Part(text=query)], role="user")
        ):
            if not is_router:
                # Let's see what the agent is thinking!
                print(f"EVENT: {event}")
            if event.is_final_response():
                final_response = event.content.parts[0].text
    except Exception as e:
        final_response = f"An error occurred: {e}"

    if not is_router:
     print("\n" + "-"*50)
     print("✅ Final Response:")
     display(Markdown(final_response))
     print("-"*50 + "\n")

    return final_response

# --- Initialize our Session Service ---
# This one service will manage all the different sessions in our notebook.
session_service = InMemorySessionService()
my_user_id = "adk_adventurer_001"

# %% [markdown]
# ---
# ## Part 1: Multi-Agent Mayhem - Sequential Workflows 🧠→🤖→🤖
#
# You've mastered single agents and memory. Now for the most advanced topic: making agents **work together in a sequence**.
#
# Some tasks are too complex for one agent. A user might ask, "Find me a great restaurant and then tell me how to get there." This requires two different skills: food recommendation and navigation.
#
# We'll build a system that can handle this by:
# 1.  Creating a new `transportation_agent` 🚗.
# 2.  Teaching our `router_agent` 🧠 to recognize these special "combo" requests.
# 3.  Writing Python code (the "orchestrator") that runs the agents in a sequence, passing the output of the first agent to the second.

# %% [markdown]
# ```
#                     +---------------------+
#                     |    User Query 🗣️     |
#                     +----------+----------+
#                                |
#                                v
#                     +---------------------+
#                     |   Router Agent 🤖    |
#                     |  (Classify Request) |
#                     +----------+----------+
#                                |
#           +--------------------+----------------------+
#           |                    |                      |
#           v                    v                      v
#   +----------------+   +--------------------+  +----------------------+
#   |  foodie_agent  |   | weekend_guide_agent|  |  day_trip_agent      |
#   |  🍣 Food Search |   | 🎉 Event Discovery |  | 🧳 Trip Planner       |
#   +----------------+   +--------------------+  +----------------------+
#           |
#           v
#   +----------------------------+            (if combo request)
#   |  Restaurant Recommendation |---------------------------+
#   |  ex: "Best sushi is at X"  |                           |
#   +----------------------------+                           v
#                                                         +-----------------------+
#                                                         | transportation_agent  |
#                                                         | 🚗 Get Directions      |
#                                                         +-----------------------+
#                                                         | Input: origin, place  |
#                                                         | Output: directions    |
#                                                         +-----------------------+
#
# Final Output: 🍽️ Recommendation + 🚗 Route Info
# ```

# %%
# --- Agent Definitions for our Specialist Team ---
# --- Agent Definition ---

day_trip_agent = Agent(
    name="day_trip_agent",
    model="gemini-2.5-flash",
    description="Agent specialized in generating spontaneous full-day itineraries based on mood, interests, and budget.",
    instruction="""
    You are the "Spontaneous Day Trip" Generator 🚗 - a specialized AI assistant that creates engaging full-day itineraries.

    Your Mission:
    Transform a simple mood or interest into a complete day-trip adventure with real-time details, while respecting a budget.

    Guidelines:
    1. **Budget-Aware**: Pay close attention to budget hints like 'cheap', 'affordable', or 'splurge'. Use Google Search to find activities (free museums, parks, paid attractions) that match the user's budget.
    2. **Full-Day Structure**: Create morning, afternoon, and evening activities.
    3. **Real-Time Focus**: Search for current operating hours and special events.
    4. **Mood Matching**: Align suggestions with the requested mood (adventurous, relaxing, artsy, etc.).

    RETURN itinerary in MARKDOWN FORMAT with clear time blocks and specific venue names.
    """,
    tools=[google_search]
)

foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are an expert food critic. Your goal is to find the absolute best food, restaurants, or culinary experiences based on a user's request. When you recommend a place, state its name clearly. For example: 'The best sushi is at **Jin Sho**.'"
)

weekend_guide_agent = Agent(
    name="weekend_guide_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a local events guide. Your task is to find interesting events, concerts, festivals, and activities happening on a specific weekend."
)

transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a navigation assistant. Given a starting point and a destination, provide clear directions on how to get from the start to the end."
)

# --- The Brain of the Operation: The Router Agent ---
# We update the router's instructions to know about the new 'combo' task.
router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about food, restaurants, or eating.
    - 'weekend_guide_agent': For queries about events, concerts, or activities happening on a specific timeframe like a weekend.
    - 'day_trip_agent': A general planner for any other day trip requests.
    - 'find_and_navigate_combo': Use this for complex queries that ask to *first find a place* and *then get directions* to it.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# We'll create a dictionary of all our individual worker agents
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent,
    "weekend_guide_agent": weekend_guide_agent,
    "transportation_agent": transportation_agent, # Add the new agent!
}

print("🤖 Agent team assembled for sequential workflows!")
# Out:
# 🤖 Agent team assembled for sequential workflows!

# %%
# --- Let's Test the Sequential Workflow! ---
import re

async def run_sequential_app():
    queries = [
        "I want to eat the best sushi in Palo Alto.", # Should go to foodie_agent
        "Are there any cool outdoor concerts this weekend?", # Should go to weekend_guide_agent
        "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station." # Should trigger the COMBO
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        if chosen_route == 'find_and_navigate_combo':
            print("\n--- Starting Find and Navigate Combo Workflow ---")

            # STEP 2a: Run the foodie_agent first
            foodie_session = await session_service.create_session(app_name=foodie_agent.name, user_id=my_user_id)
            foodie_response = await run_agent_query(foodie_agent, query, foodie_session, my_user_id)

            # STEP 2b: Extract the destination from the first agent's response
            # (This is a simple regex, a more robust solution might use a structured output format)
            match = re.search(r'\*\*(.*?)\*\*', foodie_response)
            if not match:
                print("🚨 Could not determine the restaurant name from the response.")
                continue
            destination = match.group(1)
            print(f"💡 Extracted Destination: {destination}")

            # STEP 2c: Create a new query and run the transportation_agent
            directions_query = f"Give me directions to {destination} from the Palo Alto Caltrain station."
            print(f"\n🗣️ New Query for Transport Agent: '{directions_query}'")
            transport_session = await session_service.create_session(app_name=transportation_agent.name, user_id=my_user_id)
            await run_agent_query(transportation_agent, directions_query, transport_session, my_user_id)

            print("--- Combo Workflow Complete ---")

        elif chosen_route in worker_agents:
            # This is a simple, single-agent route
            worker_agent = worker_agents[chosen_route]
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_sequential_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'I want to eat the best sushi in Palo Alto.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '55227000-dcc3-4e8a-a998-cb6985dc4ac7'...
# 🚦 Router has selected route: 'foodie_agent'
#
# 🚀 Running query for agent: 'foodie_agent' in session: 'fd177da7-5831-4abd-a35e-4741b76ff054'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""For the absolute best sushi experience in Palo Alto, **Jin Sho** and **Iki Omakase Palo Alto** stand out as top contenders, with **Kanpai Sushi** offering a consistently high-quality experience.
#
# **Jin Sho** is highly praised for its great sushi, authentic Japanese food, and top-quality ingredients. While it's noted for being expensive with smaller portions, the quality of the food and presentation are consistently highlighted. Jin Sho also offers kaiseki, a traditional multi-course Japanese dinner.
#
# For a refined and modern omakase experience, **Iki Omakase Palo Alto** is an excellent choice. Chef Li, who previously honed his skills at prestigious sushi establishments in San Francisco, brings innate artistry and culinary mastery to his creations. Iki Omakase focuses on using the finest globally and locally sourced ingredients, presenting sushi as an art form with a strong foundation in Edomae sushi.
#
# **Kanpai Sushi** is another strong recommendation, known for its consistent high quality and fresh fish. It's described as having a nice ambiance and is considered a good option for a first date. Some even suggest it's a place to bring work colleagues from Tokyo, indicating a high level of authenticity and quality.
#
# Other notable mentions include **Fuki Sushi**, which is frequently cited as a top sushi restaurant in the area and offers private tatami rooms. **Araki Sushi** is also praised for its authentic Japanese dining, masterful sushi craftsmanship, and fresh ingredients, with fast service and reasonable prices."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='wanderlog.com',
#         title='wanderlog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGuUJKiqDomGoDCBTiI5PsE-w6WbAvo4fCxeUrEQvIeLEiSUOGR095PMAyByoCJWq2KLxGBcrkLbgW9y2wD8mGPTrNqfYcXKu1jrZsiEqN6xyKrYz_vvFIC2C2H0RwofVGX4Ox0x8qP6JuorE_VIzIOqBBR8YuFuf_r8gjNtWcb6tn6sLLq5TffSHGvqU-mZI4XcvI95h1TbYbL'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='reddit.com',
#         title='reddit.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFP_SPVgn0xxLdtPV-qbfm2eb20XpiIjehB9ntiLnZDH6hjPSGuhn-r7OtaQSod2ezA_eNhuYSzslW4FWJXdo66eRPUmxIgBVsIDkty-OyAajnvZb-ql7zyBT9h7FefC-Aic8GTbMq1W4yco4AQAxvZlGL2z26DDlJh3qg7S6tuhKrAl9Si4fhg_Pj0vWEQmzxPVO2AGcKIKpdCD98hs3s='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='ikiomakasepaloalto.com',
#         title='ikiomakasepaloalto.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF7n3WgtgMdglcT3eLBGLio3gEJlmEI6ReQ_W_xzlUa-snQbwUnw_5fwLQGaalsnknOzHCX_18vhLYzJLVxK1JMXP_rzrPHfQJ2VMeH8Eyb-21y28CIEH1W0nvM45k='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='quora.com',
#         title='quora.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEPoabF1Jae0HNtgrW6QEtvA1_mwDXq4t47Rs8MtpDypMjaHMG-moHGo7XJ2RjdIrpJROJ9CZvnoHJ9LW8O8cR2yAwFk90OyxI3-iKdyMElP8pWpGNFDOaIMrv8h-o5IXXABDzOkHyW8pcAmlukAiglKjUaHTAErRfKgvvcCm67HM8lQtj8cEuu77j5Rdo='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='kanpaipaloalto.com',
#         title='kanpaipaloalto.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE3Nsr9qNrfqFQC_YDPpTnHhyW50O_IdgbbX4RZ8lY4mm-4eyiXOVqB_M3r0IyEOd_hUoAU5V_hR_DU1DaShEpeK_YtZGHsBEd2kexkSgpqojK2eai8'
#       )
#     ),
#     <... 2 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=504,
#         start_index=432,
#         text='Jin Sho also offers kaiseki, a traditional multi-course Japanese dinner.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=913,
#         start_index=758,
#         text='Iki Omakase focuses on using the finest globally and locally sourced ingredients, presenting sushi as an art form with a strong foundation in Edomae sushi.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         1,
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=1231,
#         start_index=1111,
#         text="Some even suggest it's a place to bring work colleagues from Tokyo, indicating a high level of authenticity and quality."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=1376,
#         start_index=1233,
#         text='Other notable mentions include **Fuki Sushi**, which is frequently cited as a top sushi restaurant in the area and offers private tatami rooms.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#       ],
#       segment=Segment(
#         end_index=1538,
#         start_index=1377,
#         text='**Araki Sushi** is also praised for its authentic Japanese dining, masterful sushi craftsmanship, and fresh ingredients, with fast service and reasonable prices.'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF-lYuGWdjTW8vWtA5nk0821RP-wvhdGTrJKylxhJLx8ImMfsViHcW9HeyC2-sihSTIUDzrpCXYmBd8OSF4Ajebl2dDQYukcGNqHJBqC63ResgMSq5p7K2FK3_DOzZY1Vu-IceRJvwu7RaDM9bYrGuQ-qdbz-fRAjqR78WNB9sI3oBb53sHY6kUwiwab3h8nMBi7bh4Rb-uUmQX8Uaeyuo5K2iVzulqYw==">top-rated sushi restaurants Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHe5DabcpWkt9D3Rwh0tKiIJ5SqNy4sOTvEXZ_UN9MizulBVzSzylUZ8UGS6hC2sUP4QUIWZCVE8JLeSvvqUpS22k7CxW2_ZKAFuPQ33pmejz0ur2BNy2us0N-KsGy8zX7OMUPJtrSIO5mGTyK1QuYTQt667DN30OgKeB-Zf-3vt2owC9L0LZgx6UCcYORi41nEU-dMfmY=">best sushi Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHrD27X6MBKRkZ4qOVMUuKuPvIXvuEKlm2BIq7of5c_diLbjchdp-WGd1vlQYoQMXNTSw4o1LtWD91GoQG5QmLUsFd8eH5rinHk8SaC37_zTY48x2sAaiCVg3V_yivoZz9BhTejW2XiOqWLGQqqIYg7t-arctbOanNpBk0_XN_9MVT_gm5Tp3rIicKQGaW6QgoU3qZgl8d0JSM=">Palo Alto sushi reviews</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi Palo Alto',
#     'top-rated sushi restaurants Palo Alto',
#     'Palo Alto sushi reviews',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=311,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=311
#     ),
#   ],
#   prompt_token_count=82,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=82
#     ),
#   ],
#   thoughts_token_count=681,
#   tool_use_prompt_token_count=49,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=49
#     ),
#   ],
#   total_token_count=1123,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-7d9db34c-7861-47a0-bec1-660cbb705b29' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='77b321c3-972d-4fb7-b710-2b67d296f058' timestamp=1778577776.0644627
#
# --------------------------------------------------
# ✅ Final Response:
# For the absolute best sushi experience in Palo Alto, **Jin Sho** and **Iki Omakase Palo Alto** stand out as top contenders, with **Kanpai Sushi** offering a consistently high-quality experience.
#
# **Jin Sho** is highly praised for its great sushi, authentic Japanese food, and top-quality ingredients. While it's noted for being expensive with smaller portions, the quality of the food and presentation are consistently highlighted. Jin Sho also offers kaiseki, a traditional multi-course Japanese dinner.
#
# For a refined and modern omakase experience, **Iki Omakase Palo Alto** is an excellent choice. Chef Li, who previously honed his skills at prestigious sushi establishments in San Francisco, brings innate artistry and culinary mastery to his creations. Iki Omakase focuses on using the finest globally and locally sourced ingredients, presenting sushi as an art form with a strong foundation in Edomae sushi.
#
# **Kanpai Sushi** is another strong recommendation, known for its consistent high quality and fresh fish. It's described as having a nice ambiance and is considered a good option for a first date. Some even suggest it's a place to bring work colleagues from Tokyo, indicating a high level of authenticity and quality.
#
# Other notable mentions include **Fuki Sushi**, which is frequently cited as a top sushi restaurant in the area and offers private tatami rooms. **Araki Sushi** is also praised for its authentic Japanese dining, masterful sushi craftsmanship, and fresh ingredients, with fast service and reasonable prices.
# --------------------------------------------------
#
#
# ============================================================
# 🗣️ Processing New Query: 'Are there any cool outdoor concerts this weekend?'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'ebeefba8-62ff-4aa6-9634-3fca9bead4c2'...
# 🚦 Router has selected route: 'weekend_guide_agent'
#
# 🚀 Running query for agent: 'weekend_guide_agent' in session: '2d46c569-3bae-41da-8eac-d60fd26af7bf'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""This weekend, May 16-18, 2026, there are several outdoor concerts and festivals happening in various locations.
#
# Here are some options:
#
# *   **Joshua Tree, California:** The Joshua Tree Music Festival is taking place from May 14-17, 2026, offering a family-friendly campout experience with live music, movement, and mindfulness in the Mojave Desert.
# *   **Atlanta, Georgia (and surrounding metro area):** You can find various free outdoor concerts. On Friday, May 16th, options include Avalon Nights Live, Friday Night Live, Loganville Groovin' on the Green, and a Cumming City Center concert series. On Saturday, May 17th, the Atlanta Jazz Festival will be held at Piedmont Park, and additional concerts are planned for Loganville and Cumming.
# *   **St. Augustine, Florida:** The St. Augustine Amphitheatre has JJ Grey's Blackwater Sol Revue with special guests WAR and Big Bad Voodoo Daddy on Friday, May 16th. On Saturday, May 17th, Iration & SOJA will perform with special guests Tribal Seeds & Artikal Sound System as part of their "Where it all Began Summer Tour 2026".
# *   **Lenexa, Kansas (near Kansas City):** An Outdoor Concert Series will feature Pure Sweetness Entertainment on Saturday, May 17th, with genres including R&B, pop, rock, and gospel.
# *   **Bethesda, Maryland:** The Bethesda's Summer Concert series features the Jill Fulton Band on Friday, May 15th.
#
# To help me narrow down the best recommendations for you, could you please let me know which city or region you are interested in?"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='joshuatreemusicfestival.com',
#         title='joshuatreemusicfestival.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGQ23GlI-IROXLoOTp18mqGY3CZtx0IbLqBDbwdhyQVG9Rvi9gesbW0K8HP1V839u1cf9-5bZzc9xF1pGNAJL0O6Ws3n8myDP9v4Buu9HErz7Z2O5Pp_Fs7BMbMIBqc6Q=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='dolosangeles.com',
#         title='dolosangeles.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEIReWY2HQskM7-NerjxCuC_jJ6_msLXn_SOwzSawchG_UBJ5pH_gecEM6jnUgS1nougnPxp-wxVhm834hCihLJSOPW_rEZnYu90PU12jx25qfajwL2bUmDWB2hbjIYHY4eRGY5WyQfbo4m5sJ090KvmqzdI1AdZca374kAlA4='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='atlantaonthecheap.com',
#         title='atlantaonthecheap.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEQ-K96w0m1Ui_mbtcSDLsXxrZzvt-h3a201cl2bh0R_NMAqxNl0V51pYSaMnmIqptMPiTsmRNGbUGjLNduCCUQhtjaYbvxkydgSzwaP3N6hyLGEru8g4h6WDd7SvOva_JxLQcQEYUWfde3OBrs'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='theamp.com',
#         title='theamp.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEPREYAP9U2dqJVeHbGxpq7od1TeIdcRiXlendAUY8m_9nUQS8phGrzdDcQbSyv-mKFxtmC2hIHJvbztWEolzeRYFrf-AdnqRPov2-JFQk-apCP'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='visitkc.com',
#         title='visitkc.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHVoxMX1cwOfLMiQuGoyUY7UM-7HyzVoYFk6mzDJEt2vUEFXSzDIJNK1iVZd6ItVaW8iJBwtcxSk1gWcEdOU251jacIOnuH7u4RotJQXKBSeZ8xc9LIqAdgrJ_CLynHzqM4ELSdlADzqOwuvoP-F4XJkw=='
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=348,
#         start_index=137,
#         text='*   **Joshua Tree, California:** The Joshua Tree Music Festival is taking place from May 14-17, 2026, offering a family-friendly campout experience with live music, movement, and mindfulness in the Mojave Desert'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=743,
#         start_index=601,
#         text='On Saturday, May 17th, the Atlanta Jazz Festival will be held at Piedmont Park, and additional concerts are planned for Loganville and Cumming'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=1074,
#         start_index=913,
#         text='On Saturday, May 17th, Iration & SOJA will perform with special guests Tribal Seeds & Artikal Sound System as part of their "Where it all Began Summer Tour 2026"'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=1258,
#         start_index=1076,
#         text='*   **Lenexa, Kansas (near Kansas City):** An Outdoor Concert Series will feature Pure Sweetness Entertainment on Saturday, May 17th, with genres including R&B, pop, rock, and gospel'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         5,
#       ],
#       segment=Segment(
#         end_index=1374,
#         start_index=1260,
#         text="*   **Bethesda, Maryland:** The Bethesda's Summer Concert series features the Jill Fulton Band on Friday, May 15th"
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFMmFLswf5fkNFTkHBYZ55kWPd91G_Cj599s06OsqYPQ-71OAE6HySDHzMqoH_Oe6s05N2fmKFnkWHmZKt5F8fcvKx3YFWdgw9K5HphUAzCta4zB7DNOKp_Kqht-RcqF7O96msqfA3j7uIjLO99K11O5tMtmD9uqNIxjjT5JX4gqbpxavlSMPME5Dl5l8SgrGUc-s8oIDCxASDxN7I2JN6VBinE0S08kn5EKw==">open air concerts this weekend May 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGiJC4S3MUb3pBVo55UKZFlnpoPT7JceV7hrMOy8ExJGTNlV_Fgil_NBe92uI8HZtlxjIKwQGqUwYx9pHZLgumTvQjwP078kymqNCOIkJn5ofFkCDq9-IsEj46TZKuoUmGfNUneUHItSj9SExNpO_fcyU5kMkNLEmpXKoQjmsI7hC62R2wAvWynVIJb2RY0oS9_Cz2DjdDtjydgaQavHIOktwk=">outdoor concerts May 16-18 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH3ni7gyGQDQdVti4BMqCd4G8eu4ajYfrEyLjZMI3TmOGetUBzTDieq0A6IHVkoyuD3TmEOcHpxTbbi3PBDmGMPuLesucnvZW_qOWgasVOcSsQSOSrycKzXcSj6gWnullSLEiibxdmqrxizypApcunGrdaMv9pLL-upZHkM5SsxDDAYeOkmFOnbBxmBg2j52il4dpfsJuz5Do9KDzoOusKOHGodVPGcO9sq">major outdoor music festivals May 2026</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'outdoor concerts May 16-18 2026',
#     'major outdoor music festivals May 2026',
#     'open air concerts this weekend May 2026',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=372,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=372
#     ),
#   ],
#   prompt_token_count=53,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=53
#     ),
#   ],
#   thoughts_token_count=1150,
#   tool_use_prompt_token_count=507,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=507
#     ),
#   ],
#   total_token_count=2082,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-869ac67f-682d-42f2-bfc1-4dcf7bd2b479' author='weekend_guide_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='72eb9561-3411-4f5d-869a-c19d254131c8' timestamp=1778577799.842495
#
# --------------------------------------------------
# ✅ Final Response:
# This weekend, May 16-18, 2026, there are several outdoor concerts and festivals happening in various locations.
#
# Here are some options:
#
# *   **Joshua Tree, California:** The Joshua Tree Music Festival is taking place from May 14-17, 2026, offering a family-friendly campout experience with live music, movement, and mindfulness in the Mojave Desert.
# *   **Atlanta, Georgia (and surrounding metro area):** You can find various free outdoor concerts. On Friday, May 16th, options include Avalon Nights Live, Friday Night Live, Loganville Groovin' on the Green, and a Cumming City Center concert series. On Saturday, May 17th, the Atlanta Jazz Festival will be held at Piedmont Park, and additional concerts are planned for Loganville and Cumming.
# *   **St. Augustine, Florida:** The St. Augustine Amphitheatre has JJ Grey's Blackwater Sol Revue with special guests WAR and Big Bad Voodoo Daddy on Friday, May 16th. On Saturday, May 17th, Iration & SOJA will perform with special guests Tribal Seeds & Artikal Sound System as part of their "Where it all Began Summer Tour 2026".
#       )
#     ),
#     <... 5 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#         4,
#         <... 1 more items ...>,
#       ],
#       segment=Segment(
#         end_index=175,
#         start_index=69,
#         text="It's renowned for its high quality, traditional Japanese atmosphere, and excellent nigiri and sushi rolls."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#         4,
#       ],
#       segment=Segment(
#         end_index=314,
#         start_index=176,
#         text='Many reviews highlight its authentic experience, with options for tatami rooms and a sophisticated menu of specialties and classic dishes.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#         7,
#         8,
#         9,
#         5,
#       ],
#       segment=Segment(
#         end_index=382,
#         start_index=316,
#         text='Fuki Sushi is located at 4119 El Camino Real, Palo Alto, CA 94306.'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFTXZtoOhFgjPcN_jofZMWcxFBdGvJxfr4kir_xrtPPuBuhAN0qLdsg0C4kNtPjJ20KB9IKB20h4SANYRTMp_qwu5yG_wP3r6durw6wQPB1J-vjbuWiLkziSKJ7tF3gm9ThSFcyaCJAWqdC_VnhS-KL4N3nGn2taIDszhvtTBpcuJOic6xT5AFRCiPjlzUzLI6MtWSAS2VC69hMmtO19g4=">Fuki Sushi Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHBvZgQHIoNjXvQRGqsYail3TNFSpg3VJIVuPy6A3TdWCUt3u2fmqCDfSaYw_iBDUAwmFUX6xe85KgKtD4WJUEFa-gOvF2DtMXyV8Jk1HUiZ9nrT4JQHyxcXSj6h1nZGzbNmqDt4bAmzvcrDVQPxqEbbVL00skSTaxCXNZNMqW5wRINvHb2kGx9yOgLG05xnjBHJMTjfuhG16QtwI0iXnbJKHdy3fX-d8q8drX6SC2XhktTCU2Q-2OSPDzUTw==">directions from Palo Alto Caltrain station to Fuki Sushi</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi Palo Alto',
#     'top sushi restaurants Palo Alto reviews',
#     'directions from Palo Alto Caltrain station to Fuki Sushi',
#     'Fuki Sushi Palo Alto address',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=244,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=244
#     ),
#   ],
#   prompt_token_count=93,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=93
#     ),
#   ],
#   thoughts_token_count=827,
#   tool_use_prompt_token_count=825,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=825
#     ),
#   ],
#   total_token_count=1989,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-2370135a-6f2d-4ce6-a4db-3812308242e7' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='9833f051-dbde-45f2-b925-6434e8362a11' timestamp=1778577820.2178519
#
# --------------------------------------------------
# ✅ Final Response:
# The absolute best sushi in Palo Alto can be found at **Fuki Sushi**. It's renowned for its high quality, traditional Japanese atmosphere, and excellent nigiri and sushi rolls. Many reviews highlight its authentic experience, with options for tatami rooms and a sophisticated menu of specialties and classic dishes.
#
# Fuki Sushi is located at 4119 El Camino Real, Palo Alto, CA 94306.
#
# To get to Fuki Sushi from the Palo Alto Caltrain Station:
#
# 1.  **Walk to the bus stop:** Exit the Caltrain station and walk to the nearest bus stop.
# 2.  **Take the 22 bus:** Board the VTA Bus #22 (Palo Alto - San Jose) going southbound on El Camino Real. This bus route runs along El Camino Real, which is where Fuki Sushi is located.
# 3.  **Exit at El Camino Real & Ventura Ave:** Fuki Sushi is a short walk from the bus stop at El Camino Real & Ventura Ave. The restaurant will be on your left if you are heading southbound.
#
# The bus ride typically takes about 10-15 minutes, depending on traffic.
# --------------------------------------------------
#
# 💡 Extracted Destination: Fuki Sushi
#
# 🗣️ New Query for Transport Agent: 'Give me directions to Fuki Sushi from the Palo Alto Caltrain station.'
#
# 🚀 Running query for agent: 'transportation_agent' in session: 'c2bc89a5-df54-425a-bee1-04854c0b502d'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""To get to

#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=59
#     ),
#   ],
#   thoughts_token_count=164,
#   tool_use_prompt_token_count=52,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=52
#     ),
#   ],
#   total_token_count=395,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-bb210ad4-cb58-4714-b3fe-2915fec10eef' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='f72ea74d-ee1f-4374-b8f3-84ac08755ed9' timestamp=1778577840.0302224
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Fuki Sushi from the Palo Alto Caltrain Station, follow these directions:
#
# 1.  Start at the Palo Alto Caltrain Station located at 95 University Avenue, Palo Alto, CA.
# 2.  Head southeast on University Avenue toward Alma Street.
# 3.  Turn right onto Alma Street.
# 4.  Continue on Alma Street, which will become El Camino Real.
# 5.  Fuki Sushi is located at 4119 El Camino Real, Palo Alto, CA 94306. The restaurant will be on your right.
# --------------------------------------------------
#
# --- Combo Workflow Complete ---

# %% [markdown]
# ---
# ### Part 2 (The ADK Way): Multi-Agent Mayhem with `SequentialAgent` 🧠→⛓️→🤖
#
# You've seen how to manually link agents together with custom Python code. It works, but it can get complicated. Now, let's refactor our workflow to use a powerful, built-in ADK feature designed specifically for this: the **`SequentialAgent`**.
#
# The `SequentialAgent` is a *workflow agent*. It's not powered by an LLM itself; instead, its only job is to execute a list of other agents in a strict, predefined order.
#
# The real magic ✨ is how it passes information. The ADK uses a shared `state` dictionary that each agent in the sequence can read from and write to.
#
# **Our New Workflow:**
#
# 1.  **Foodie Agent**: Finds the restaurant and saves the name to `state['destination']`.
# 2.  **Transportation Agent**: Automatically reads `state['destination']` and uses it to find directions.
#
# This means we no longer need custom Python code to extract text or build new queries! The ADK handles the plumbing for us.

# %% [markdown]
# ```
# +-------------------------------+
# |  find_and_navigate_agent 🧭   |
# | SequentialAgent:             |
# | 1. Find destination          |
# | 2. Get directions            |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +------------------------+
# | foodie_agent 🍣 |   | transportation_agent 🚗 |
# | Finds place     |   | Uses {destination}     |
# | Output: 'Jin Sho'|   | Output: Directions     |
# +----------------+   +------------------------+
#
# Final Output: 🍣 Restaurant + 🚗 Route
# ```

# %%
# --- Agent Definitions for our Specialist Team (Refactored for Sequential Workflow) ---

# ✨ CHANGE 1: We tell foodie_agent to save its output to the shared state.
# Note the new `output_key` and the more specific instruction.
foodie_agent = Agent(
    name="foodie_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment and nothing else.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="destination"  # ADK will save the agent's final response to state['destination']
)

# ✨ CHANGE 2: We tell transportation_agent to read from the shared state.
# The `{destination}` placeholder is automatically filled by the ADK from the state.
transportation_agent = Agent(
    name="transportation_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are a navigation assistant. Given a destination, provide clear directions.
    The user wants to go to: {destination}.

    Analyze the user's full original query to find their starting point.
    Then, provide clear directions from that starting point to {destination}.
    """,
)

# ✨ CHANGE 3: Define the SequentialAgent to manage the workflow.
# This agent will run foodie_agent, then transportation_agent, in that exact order.
find_and_navigate_agent = SequentialAgent(
    name="find_and_navigate_agent",
    sub_agents=[foodie_agent, transportation_agent],
    description="A workflow that first finds a location and then provides directions to it."
)

weekend_guide_agent = Agent(
    name="weekend_guide_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="You are a local events guide. Your task is to find interesting events, concerts, festivals, and activities happening on a specific weekend."
)

# --- The Brain of the Operation: The Router Agent ---

# We update the router to know about our new, powerful SequentialAgent.
router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about food, restaurants, or eating.
    - 'weekend_guide_agent': For queries about events, concerts, or activities happening on a specific timeframe like a weekend.
    - 'day_trip_agent': A general planner for any other day trip requests.
    - 'find_and_navigate_agent': Use this for complex queries that ask to *first find a place* and *then get directions* to it.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# We create a dictionary of all our executable agents for easy lookup.
# This now includes our powerful new workflow agent!
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent,
    "weekend_guide_agent": weekend_guide_agent,
    "find_and_navigate_agent": find_and_navigate_agent, # Add the new sequential agent
}

print("🤖 Agent team assembled with a SequentialAgent workflow!")
# Out:
# 🤖 Agent team assembled with a SequentialAgent workflow!

# %%
# --- Let's Test the Streamlined Workflow! ---

async def run_sequential_app():
    queries = [
        "I want to eat the best sushi in Palo Alto.", # Should go to foodie_agent
        "Are there any cool outdoor concerts this weekend?", # Should go to weekend_guide_agent
        "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station." # Should trigger the SequentialAgent
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        # This logic is now much simpler! The SequentialAgent is treated just like any other worker.
        if chosen_route in worker_agents:
            worker_agent = worker_agents[chosen_route]
            print(f"--- Handing off to {worker_agent.name} ---")
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
            print(f"--- {worker_agent.name} Complete ---")
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_sequential_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'I want to eat the best sushi in Palo Alto.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '2d1610cf-2bf3-4534-93d3-b2c7ef32825a'...
# 🚦 Router has selected route: 'foodie_agent'
# --- Handing off to foodie_agent ---
#
# 🚀 Running query for agent: 'foodie_agent' in session: 'b1e87a39-9be7-4e40-9909-eee7474f1bda'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Jin Sho.'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFNai2KTYyksRe8yZEQ5siZqbWwnfhmF1P6t8C1DGq0iaoNH_zK9Tf5aveW1vcQ0oRKJdmvD2jHQe9KA-xpGaZUEoWbiErrYiRwTDKYrQF7ENXtOot_f2Cvwy1D5MMRySM053OqCWAqfaxM-8eI1xtgNvc0UxWo6M8dEPnVn6IJWeADA_TTBvzEMplz33hWcsbjf6kMGYVDKlM=">Palo Alto sushi reviews</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGTE_KuAzL2bg2a_n1RUKVC01dB76Q60Yx4NJyVC4eAYsYg243GARJWFvKc35qo5y7MIRqmbChNM6Ci5rIg65pUeyM1tR8nAuYAuFD0TucoZESHLKe3kWqazxrZbRB_-S6X8fC6-TwaoIxjcCcBRZhLgjQF_3TM2c-WwnJoJKyiWY5ZThRrGGFaifgBsGgoBT20SPVES1Tr1yE=">best sushi in Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGYltHmBdhBGrBCRwPusQD75Ba3UG8S7J7zNu9-A7JvFBzZeYhfZO5Tt75HcjFXYWAV1BuljHZb4bHPEJlOa-KByX67qZe-dJI_9LuZkknHOQ9b1BSN_jkL_Sia4gFu9knbILeFs9kUWy7x1OvfsZMnB6sMWS2HSU8qaAEksxrH5Xs0lD4ZmzOpzsCbxWSRf2cylkn3r9yeNAgO8-t8KML5a0h73lX7Ag==">top-rated sushi restaurants Palo Alto</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi in Palo Alto',
#     'top-rated sushi restaurants Palo Alto',
#     'Palo Alto sushi reviews',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=3,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=3
#     ),
#   ],
#   prompt_token_count=97,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=97
#     ),
#   ],
#   thoughts_token_count=579,
#   tool_use_prompt_token_count=54,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=54
#     ),
#   ],
#   total_token_count=733,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-bd222a88-2d78-4a09-943f-93d5a6be87a1' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Jin Sho.'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='ad3b2f75-514b-4547-bca8-78dee7feb979' timestamp=1778577889.6456122
#
# --------------------------------------------------
# ✅ Final Response:
# Jin Sho.
# --------------------------------------------------
#
# --- foodie_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Are there any cool outdoor concerts this weekend?'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'ae922bad-f450-4635-9715-b07502d0914e'...
# 🚦 Router has selected route: 'weekend_guide_agent'
# --- Handing off to weekend_guide_agent ---
#
# 🚀 Running query for agent: 'weekend_guide_agent' in session: '56b964aa-94fc-4ff5-a02d-3401747ec28d'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="

#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=515,
#         start_index=438,
#         text='You can also enjoy craft beer gardens, food trucks, and family entertainment.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         1,
#       ],
#       segment=Segment(
#         end_index=743,
#         start_index=659,
#         text="It's described as Ohio's largest art and music festival, celebrating rock and metal."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=972,
#         start_index=876,
#         text='Beyond strawberries, the festival offers live music, numerous food vendors, and arts and crafts.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=1177,
#         start_index=973,
#         text='*   **Las Vegas, Nevada:** If electronic dance music is your scene, **EDC Las Vegas (Electric Daisy Carnival)** is on from May 15-17 at the Las Vegas Motor Speedway, featuring a massive lineup of artists.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#       ],
#       segment=Segment(
#         end_index=1473,
#         start_index=1379,
#         text='This is a free event, and attendees are encouraged to bring picnics, lawn chairs, or blankets.'
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQH1xFwCZ1yzUzmYzZ95YPVBK_5kjP3Pddxjdsp9cYChurlN3Iol1YMAfEmGXfM5FY_cBtqgmi2O1g4V8fIV96JmiJpwFVQ1OILLEBnVbaEGToYondEW50o59b3RjzJ4pubwsWxtGwPi_Q95_pPtCx9PSchymrCbFg3tqGLNVGJaLhGmpfIFrV1e7K9l0F4mJZQsdEyNr7nC3AeGuLkpigKvdg==">music festivals May 16-17 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGpT1Lw6ahMWvOvApC84_l69Gmc04gNT-JU_3fSKo8EV6APEmEi0r6StF0T49pfbgHJBP7rtpHuXBUAxxp3Vhzc0pTfzyGoWxR-LX5rHz-HOT5CkbZH-MkMOANewG5hXooacLq_mZumAfM_6AWwcEqJek7LNzGtZls26-a9umq4ZKilHJXZ-P_3dPJL6qRCo4TVSwQIyYccA9VeMTXYBDQ4sf4=">outdoor concerts May 16-17 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEJ2y0AovAnif2_8PfxIVbY3UUI560VvtcpNNrPh9nhGnkeGpfo-59peHS4V07R7i5qGfUUgRuP7blSWK8HsanYECR6EoJ04T0-nyhbcKpUGwDaqVGkosA2NGXImjHWy-6yiMXPvbUQJ4NV8_UrtgzFXZlOuLB1eeHzXgOaU1GzPGhO5L0keGQPvtFvQ1Tg7BLOe-V5OYRMb6Lxtql10GPDRUHokyuKrU8=">cool outdoor events this weekend 2026</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'outdoor concerts May 16-17 2026',
#     'music festivals May 16-17 2026',
#     'cool outdoor events this weekend 2026',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=532,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=532
#     ),
#   ],
#   prompt_token_count=53,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=53
#     ),
#   ],
#   thoughts_token_count=1766,
#   tool_use_prompt_token_count=1057,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1057
#     ),
#   ],
#   total_token_count=3408,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-06aee161-890c-43a0-8c02-e49b316239dc' author='weekend_guide_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='4f2308c2-6c7e-4e22-a07e-356388d8e614' timestamp=1778577918.1650658
#
# --------------------------------------------------
# ✅ Final Response:
# This weekend, May 16-17, 2026, offers a variety of exciting outdoor concerts and music festivals across North America. Here are some options that might pique your interest:
#
# **United States:**
#
# *   **Pleasant Hill, California:** The **Pleasant Hill Art, Wine & Music Festival** is happening on both Saturday and Sunday. This free event features 13 live performances spanning rock, blues, dance, and classic genres across multiple stages. You can also enjoy craft beer gardens, food trucks, and family entertainment.
# *   **Columbus, Ohio:** For fans of heavier music, the **Sonic Temple Art & Music Festival** runs from May 14-17 at the Historic Crew Stadium. It's described as Ohio's largest art and music festival, celebrating rock and metal.
# *   **Ventura, California:** The **California Strawberry Festival** will take place on May 16-17 at the Ventura County Fairgrounds. Beyond strawberries, the festival offers live music, numerous food vendors, and arts and crafts.
# *   **Las Vegas, Nevada:** If electronic dance music is your scene, **EDC Las Vegas (Electric Daisy Carnival)** is on from May 15-17 at the Las Vegas Motor Speedway, featuring a massive lineup of artists.
# *   **Lenexa, Kansas:** Enjoy a more relaxed outdoor experience at the **Outdoor Concert Series** on Sunday, May 17. "Pure Sweetness Entertainment" will be performing R&B, pop, rock, and gospel music. This is a free event, and attendees are encouraged to bring picnics, lawn chairs, or blankets.
# *   **Joshua Tree, California:** The **24th Spring Joshua Tree Music Festival** is ongoing from May 14-17, offering four nights and three days of live music, movement, mindfulness, and desert magic.
# *   **Denver, Colorado:** At the iconic Red Rocks Park & Amphitheatre, **LIGHTCODE BY LSDREAM** and **LSDREAM presents: DREAMROCKS II** with supporting acts are scheduled for May 16.
#
# **Canada:**
#
# *   **Montreal, Quebec:** The **Pouzza Fest**, a punk rock music festival, will be taking over downtown Montreal from May 15-17. It features over 150 bands performing in various venues within walking distance of each other.
#
# To help me narrow down further options or find something more specific to your taste, could you let me know your preferred location or any specific genres you enjoy?
# --------------------------------------------------
#
# --- weekend_guide_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '7dfc2bbd-c78f-44d2-bc4f-ff7f3f3320f2'...
# 🚦 Router has selected route: 'find_and_navigate_agent'
# --- Handing off to find_and_navigate_agent ---
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: 'bf2a1332-7d06-424b-988d-f458ca74d286'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Jin Sho'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFvIe9C2SHwJJHyMdogYAVOxSas8SkGBMhBWI-8KcmjA9YdQ4qOiVv_Yc80GhnakQvGpa2IfgMuymJ8l6pZoEEteuRpK8vnEjI7xSHNi1P_pcdjoaUfUVItjL6uaV45CTdCe3Pk1qUE15hbxtJxAnPQTjBQN3TH0379u8IZODJ3Wkk5TLwEajsMpYySw29lT27Z8KNBZJrp9tsJZ54=">Jin Sho Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGHKbYco-L0VlMeNcmhgnXUfPH7HZ53gdzbK36Oin-zMBBw2ZzghUdXLJ8NbqiBimNoWcYqOt66PV37HBVFom3VHi3k_EMYsbVSiaO8MYbDXotI_ZW4JcaHoi3Tpdk5PZjsQTaORX2s0DUKuxkY2bjYMD1oVMdfaD_ieyVoCLnGSP_McSoYo01lufDU-MHrkIVu_mKacFylJgf2qvNdcvsT_FUXlmOEx7cwyN8_HDWbhuLVLCX6GGt2lA==">directions from Palo Alto Caltrain station to Jin Sho</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF7ZtHFZFPxW7Kv8UQY0On_FTQ-i4kP-LU1Hue2E5S3xy2axQYjT61hHfUhQg9vGpsmrGfJMlspwPD7LOs47G-VsKeCJThwlnL_icNCR8GqfssK-UAaceJP5BnbdR3yRmrcApMpXOTrJh6X4CRpeXZ0yKzraG86QB87VxD3BgV6bGNEQilqARlfpmmY1vRS7r2Viro-t8XcATt50wPHwT-_YgZk0sY=">Palo Alto Caltrain station address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi Palo Alto',
#     'highest rated sushi Palo Alto',
#     'top sushi restaurants Palo Alto',
#     'directions from Palo Alto Caltrain station to Jin Sho',
#     'Jin Sho Palo Alto address',
#     <... 1 more items ...>,
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2
#     ),
#   ],
#   prompt_token_count=108,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=108
#     ),
#   ],
#   thoughts_token_count=1107,
#   tool_use_prompt_token_count=1035,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=1035
#     ),
#   ],
#   total_token_count=2252,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-c6a4be3f-6d1f-411d-875b-1d90894175f4' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Jin Sho'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='c61254e3-9a53-4f53-a267-079b3ec6bdc6' timestamp=1778577969.5991352
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""To get to Jin Sho, located at 454 California Avenue, Palo Alto, CA 94306, from the Caltrain station in Palo Alto, located at 95 University Avenue, Palo Alto, CA, you have a few options:
#
# **Walking (approximately 25-30 minutes):**
#
# 1.  Exit the Caltrain station and head southwest on University Avenue towards Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Continue on Alma Street until you reach California Avenue.
# 4.  Turn left onto California Avenue. Jin Sho will be on your right at 454 California Avenue.
#
# **Public Transit (approximately 15-20 minutes, including wait time):**
#
# *   You can take a local VTA bus from the Palo Alto Caltrain Station. Look for routes that travel towards California Avenue. The VTA 89 route connects to the California Avenue Caltrain station, which is closer to Jin Sho.
#
# **Ride-Share/Taxi (approximately 5-10 minutes, depending on traffic):**
#
# *   A ride-sharing service or a taxi would be the quickest option. The distance between the Caltrain station and Jin Sho is relatively short."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='jinshorestaurant.com',
#         title='jinshorestaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHUsjxFfqdZ4IcXm1jjPR5ybPRNNxZkfi3uRPbg7Wtc3Mz2O_XGHWPGo98DS14GSzo6JizyA94xGBPYdwb6hGND6-UGk4qkGKf_F4J1eoKoyp_cGj1a1sPIw7Lm9S505kOEby8='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='jinshorestaurant.com',
#         title='jinshorestaurant.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFxDsi-if2kGC8vkWH9D98z3KuprCwgnWZZa16cTu8aQZLUucymBz45LGCOwiLDrVmZDwnjOd2Jj7NKxkawXWSf7Eyjxb9nTeFDKzcmnHoiWf8OQK62o6239pUmXw=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='waze.com',
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE1h3spvZtNwQUzFqmUpvuXT9ak9Vd4MltrKsu9PCh7Z480F-JzeqtJV4HRTilrgrv7iLbOSDZyqsxh1acL9vS0m4DJI_t02cKtuaZvNQzUQclLfRkMRJZslvOAGFZmtc4WEQnpiaQtSpUVUFT968witcux3pvZsP8GtoIjlcX7X1HATPWedN4WUmuet2vMjbbTb9jjnKAMlxqaid5XaCpY'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='restaurants-info.com',
#         title='restaurants-info.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHYcByq4NaoQH49pgS8I1F4QQwoPqq8jjerJ89dr0KPmZ1dAxLlU0nLXOCQIUjDe7gcu2Ar711EMrXQ0v19XsLNScWoDsg9_PE2cPupx2Ik9iwoa8vwuYx7JeSWgjc8dA=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='waze.com',
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQF7QYDmKOhX8HlZBj57mJ5F_Jm0DAOUZrccIqSq3eqWJleqz8VR3R3UYZozOsiKKrMpNX-tJ6X1HqC0VphfPAamNxzKST44JiPWyvTdll_CVosmZRmLB7vADaSarGflJzavLSpHY0vugK8_D-48T4maGssx-jNwDfkPmXZGdsEhygJLcwX7OLF1LzfA6JTtghEtoI0LHBSNyTUNcM7vvlEU8jSZCYNZJDWUX7DJS3kAnNRWUw=='
#       )
#     ),
#     <... 2 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=72,
#         text='To get to Jin Sho, located at 454 California Avenue, Palo Alto, CA 94306'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=160,
#         start_index=72,
#         text=', from the Caltrain station in Palo Alto, located at 95 University Avenue, Palo Alto, CA'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=510,
#         start_index=456,
#         text='Jin Sho will be on your right at 454 California Avenue'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         6,
#         5,
#       ],
#       segment=Segment(
#         end_index=805,
#         start_index=710,
#         text='The VTA 89 route connects to the California Avenue Caltrain station, which is closer to Jin Sho'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGDNVuheD7zAi-HKTs6LOBr-rI4hoF8D_33cvSxBLikiYoRW_xrV8OQcSEL5p7-YPjI6Wy8tt7pK01giaqdqJtwMTiq8HDJAlgehYB2GpJTjuMNi4ctuOMsFxo2emmUhbL5cDFuycBUbLM1tD6Zj7c8WXvxpgjiQqvYa9ZR7XihFoopWBYyhky2Qfof9B7FWgOlTBXQu22cMG6h2k2S63j57Cx1AtTfvpFhjWzGvTzYu0_-UqAHf-nEmQ==">directions from Palo Alto Caltrain station to Jin Sho</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQG4kPJ1qBmOKTVtrLqL67rRMhy_xTzl_La16S_zcXUohPtpuTrINWwaDsqY7sOgqVC4mL9AG6ahEEi3yNR2_hS7eJeKfnkPsU7s0e3PhKOf5AiCHWzcavb1z7CEuI2pH_GQGLJctWcF1lp-PzZfgPJUTScRznSyodU6VnaLaLJfcrPhskKSNV1tIfR77xWll-Rh78TpK2FGJ5mcQZM=">Jin Sho Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHotpmuwDl8Kbz-L6UGKQBfQ1IBv_9knV5jcXqR1xjE2af6xWfJ8u80d1kfV7fV53veqAq7gQa_c_8kdMme2iAzRwLJG4nRsdErRUux_p_HSKfheA3q5eeoarLxrspETkViUhV3f-nryZnz4etJ0MP6aclVsQN5I4myKb2L0WZLvCeAuMESmDofe0J82zonaieK-tx5sAW015wxVBno3DcPzNDV8hM=">Caltrain Palo Alto station address</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Jin Sho Palo Alto address',
#     'Caltrain Palo Alto station address',
#     'directions from Palo Alto Caltrain station to Jin Sho',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=258,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=258
#     ),
#   ],
#   prompt_token_count=110,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=110
#     ),
#   ],
#   thoughts_token_count=192,
#   tool_use_prompt_token_count=52,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=52
#     ),
#   ],
#   total_token_count=612,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-c6a4be3f-6d1f-411d-875b-1d90894175f4' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='e126e525-2808-4105-b840-faf5ee79b879' timestamp=1778577990.3250318
#
# --------------------------------------------------
# ✅ Final Response:
# To get to Jin Sho, located at 454 California Avenue, Palo Alto, CA 94306, from the Caltrain station in Palo Alto, located at 95 University Avenue, Palo Alto, CA, you have a few options:
#
# **Walking (approximately 25-30 minutes):**
#
# 1.  Exit the Caltrain station and head southwest on University Avenue towards Alma Street.
# 2.  Turn right onto Alma Street.
# 3.  Continue on Alma Street until you reach California Avenue.
# 4.  Turn left onto California Avenue. Jin Sho will be on your right at 454 California Avenue.
#
# **Public Transit (approximately 15-20 minutes, including wait time):**
#
# *   You can take a local VTA bus from the Palo Alto Caltrain Station. Look for routes that travel towards California Avenue. The VTA 89 route connects to the California Avenue Caltrain station, which is closer to Jin Sho.
#
# **Ride-Share/Taxi (approximately 5-10 minutes, depending on traffic):**
#
# *   A ride-sharing service or a taxi would be the quickest option. The distance between the Caltrain station and Jin Sho is relatively short.
# --------------------------------------------------
#
# --- find_and_navigate_agent Complete ---

# %% [markdown]
# ### Running the Streamlined App
#
# Notice how much simpler the code below is. There is no longer a special `if chosen_route == 'find_and_navigate_combo':` block with custom logic.
#
# The `find_and_navigate_agent` is now a self-contained unit. We can treat it just like any other agent, hand it the query, and trust the `SequentialAgent` to handle all the internal steps. This makes our main application code much cleaner and easier to read.

# %% [markdown]
# ---
# ## Iterative Ideas with `LoopAgent` 🧠→🔁→🤖
#
# Sometimes a task isn't a straight line; it's a loop of refinement. A user might ask for a plan, but have constraints that require checking and re-planning. For this, the ADK provides the **`LoopAgent`**.
#
# The `LoopAgent` executes a sequence of sub-agents repeatedly until a condition is met. This is perfect for workflows involving trial and error, like planning a trip with a tight schedule.
#
# **Our New Workflow: The Perfectionist Planner**
#
# 1. **Planner Agent**: Proposes an itinerary (e.g., a museum and a restaurant).
# 2. **Critic Agent**: Checks the plan against a constraint (e.g., "Is the travel time between these two places less than 30 minutes?").
# 3. **Refiner Agent**: If the critic finds a problem, this agent takes the feedback and creates a new, improved plan. If the critic is happy, it calls a special `exit_loop` tool to stop the process.
#
# The `LoopAgent` manages this cycle, ensuring we don't get stuck in an infinite loop by setting a `max_iterations` limit.

# %% [markdown]
# ```
# +-------------------------------+
# |  iterative_planner_agent 🔁   |
# | SequentialAgent:              |
# | 1. Propose Plan               |
# | 2. Refine in loop (≤ 3 times) |
# +---------------+---------------+
#                 |
#      +----------+----------+
#      |                     |
#      v                     v
# +----------------+   +-----------------------+
# | planner_agent  |   | refinement_loop 🔁     |
# | Propose plan   |   | LoopAgent             |
# | e.g., Activity +  | 1. Critic (time check) |
# | Restaurant       | 2. Refiner (fix/exit)   |
# +----------------+   +-----------------------+
#
# Uses shared state: {current_plan}, {criticism}
# Exits when: "Plan is feasible..."
#
# ```

# %%
# --- Agent Definitions for an Iterative Workflow ---

# A tool to signal that the loop should terminate
COMPLETION_PHRASE = "The plan is feasible and meets all constraints."
def exit_loop(tool_context: ToolContext):
  """Call this function ONLY when the plan is approved, signaling the loop should end."""
  print(f"  [Tool Call] exit_loop triggered by {tool_context.agent_name}")
  tool_context.actions.escalate = True
  return {}

# Agent 1: Proposes an initial plan
planner_agent = Agent(
    name="planner_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a trip planner. Based on the user's request, propose a single activity and a single restaurant. Output only the names, like: 'Activity: Exploratorium, Restaurant: La Mar'.",
    output_key="current_plan",
)

# Agent 2 (in loop): Critiques the plan
critic_agent = Agent(
    name="critic_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction=f"""You are a logistics expert. Your job is to critique a travel plan. The user has a strict constraint: total travel time must be short.
    Current Plan: {{current_plan}}
    Use your tools to check the travel time between the two locations.
    IF the travel time is over 45 minutes, provide a critique, like: 'This plan is inefficient. Find a restaurant closer to the activity.'
    ELSE, respond with the exact phrase: '{COMPLETION_PHRASE}'""",
    output_key="criticism",
)

# Agent 3 (in loop): Refines the plan or exits
refiner_agent = Agent(
    name="refiner_agent", model="gemini-2.5-flash", tools=[google_search, exit_loop],
    instruction=f"""You are a trip planner, refining a plan based on criticism.
    Original Request: {{session.query}}
    Critique: {{criticism}}
    IF the critique is '{COMPLETION_PHRASE}', you MUST call the 'exit_loop' tool.
    ELSE, generate a NEW plan that addresses the critique. Output only the new plan names, like: 'Activity: de Young Museum, Restaurant: Nopa'.""",
    output_key="current_plan",
)

# ✨ The LoopAgent orchestrates the critique-refine cycle ✨
refinement_loop = LoopAgent(
    name="refinement_loop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=3
)

# ✨ The SequentialAgent puts it all together ✨
iterative_planner_agent = SequentialAgent(
    name="iterative_planner_agent",
    sub_agents=[planner_agent, refinement_loop],
    description="A workflow that iteratively plans and refines a trip to meet constraints."
)

print("🤖 Agent team updated with an iterative LoopAgent workflow!")
# Out:
# 🤖 Agent team updated with an iterative LoopAgent workflow!

# %% [markdown]
# ---
# ## Parallel Power with `ParallelAgent` 🧠→⚡️→🤖🤖🤖
#
# What if a user wants to find multiple, unrelated things at once? "Find me a museum, a concert, AND a restaurant." Running these searches one by one is slow and inefficient.
#
# Enter the **`ParallelAgent`**. This workflow agent executes a list of sub-agents *concurrently*, dramatically speeding up tasks that can be performed independently.
#
# **Our New Workflow: The Multi-Researcher**
#
# 1.  **Parallel Agent**: Simultaneously runs three specialist agents:
#     - `MuseumFinderAgent`: Finds a museum.
#     - `ConcertFinderAgent`: Finds a concert.
#     - `FoodieAgent`: Finds a restaurant.
# 2.  **Synthesis Agent**: Once all three parallel searches are complete, this final agent gathers the results (which were saved to the shared `state`) and formats them into a single, neat summary for the user.
#
# This pattern lets us get a lot of work done, fast! 🚀

# %% [markdown]
# ```
# +-------------------------------+
# |  parallel_planner_agent ⚡     |
# | SequentialAgent:              |
# | 1. Run parallel research      |
# | 2. Synthesize results         |
# +---------------+---------------+
#                 |
#      +----------+----------------------+
#      |                                 |
#      v                                 v
# +-------------------------+       +-----------------------------+
# | parallel_research_agent ⚡   |   | synthesis_agent 📋          |
# | ParallelAgent:              |   | Combine results            |
# | - museum_finder_agent 🖼️     |   | Output: Bulleted summary   |
# | - concert_finder_agent 🎵    |   +-----------------------------+
# | - restaurant_finder_agent 🍽️ |
# +-------------------------+
#
# Final Output:
# • Museum: XYZ
# • Concert: Artist at Venue
# • Restaurant: ABC
# ```

# %%
# --- Agent Definitions for a Parallel Workflow ---

# Specialist Agent 1
museum_finder_agent = Agent(
    name="museum_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are a museum expert. Find the best museum based on the user's query. Output only the museum's name.",
    output_key="museum_result"
)

# Specialist Agent 2
concert_finder_agent = Agent(
    name="concert_finder_agent", model="gemini-2.5-flash", tools=[google_search],
    instruction="You are an events guide. Find a concert based on the user's query. Output only the concert name and artist.",
    output_key="concert_result"
)

# We can reuse our foodie_agent for the third parallel task!
# Just need to give it a new output_key for this workflow.
# restaurant_finder_agent = foodie_agent.copy(update={"output_key": "restaurant_result"})
restaurant_finder_agent = Agent(
    name="restaurant_finder_agent",
    model="gemini-2.5-flash",
    tools=[google_search],
    instruction="""You are an expert food critic. Your goal is to find the best restaurant based on a user's request.

    When you recommend a place, you must output *only* the name of the establishment.
    For example, if the best sushi is at 'Jin Sho', you should output only: Jin Sho
    """,
    output_key="restaurant_result" # Set the correct output key for this workflow
)


# ✨ The ParallelAgent runs all three specialists at once ✨
parallel_research_agent = ParallelAgent(
    name="parallel_research_agent",
    sub_agents=[museum_finder_agent, concert_finder_agent, restaurant_finder_agent]
)

# Agent to synthesize the parallel results
synthesis_agent = Agent(
    name="synthesis_agent", model="gemini-2.5-flash",
    instruction="""You are a helpful assistant. Combine the following research results into a clear, bulleted list for the user.
    - Museum: {museum_result}
    - Concert: {concert_result}
    - Restaurant: {restaurant_result}
    """
)

# ✨ The SequentialAgent runs the parallel search, then the synthesis ✨
parallel_planner_agent = SequentialAgent(
    name="parallel_planner_agent",
    sub_agents=[parallel_research_agent, synthesis_agent],
    description="A workflow that finds multiple things in parallel and then summarizes the results."
)

print("🤖 Agent team supercharged with a ParallelAgent workflow!")
# Out:
# 🤖 Agent team supercharged with a ParallelAgent workflow!

# %% [markdown]
# ---
# ### Final Step: Updating the Router and Running the App
#
# Now we just have one last thing to do: make our `router_agent` aware of these powerful new workflows! We'll add `iterative_planner_agent` and `parallel_planner_agent` to its list of available options.
#
# Then we can run our app with new queries designed to trigger these advanced, multi-agent workflows.

# %% [markdown]
# ```
#                     +---------------------+
#                     |    User Query 🗣️     |
#                     +----------+----------+
#                                |
#                                v
#                     +---------------------+
#                     |   Router Agent 🤖    |
#                     |  (Classify Request) |
#                     +----------+----------+
#                                |
#       +-----------+-----------+-----------+-----------+------------+
#       |           |           |           |           |            |
#       v           v           v           v           v            v
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# | foodie_agent|  | find_and_navigate|  | iterative_planner|  | parallel_planner |  | day_trip_agent  |
# | 🍣 Food Only |  | 🧭 Seq Workflow   |  | 🔁 Loop Workflow  |  | ⚡ Parallel Tasks |  | 🧳 Basic Plan     |
# +-------------+  +------------------+  +------------------+  +------------------+  +-----------------+
# ```

# %%
# --- The ULTIMATE Router Agent --- #

router_agent = Agent(
    name="router_agent",
    model="gemini-2.5-flash",
    instruction="""
    You are a master request router. Your job is to analyze a user's query and decide which of the following agents or workflows is best suited to handle it.
    Do not answer the query yourself, only return the name of the most appropriate choice.

    Available Options:
    - 'foodie_agent': For queries *only* about finding a single food place.
    - 'find_and_navigate_agent': For queries that ask to *first find a place* and *then get directions* to it.
    - 'iterative_planner_agent': For planning a trip with a specific constraint that needs checking, like travel time.
    - 'parallel_planner_agent': For queries that ask to find multiple, independent things at once (e.g., a museum AND a concert AND a restaurant).
    - 'day_trip_agent': A general planner for any other simple day trip requests.

    Only return the single, most appropriate option's name and nothing else.
    """
)

# The master dictionary of all our executable agents and workflows
worker_agents = {
    "day_trip_agent": day_trip_agent,
    "foodie_agent": foodie_agent, # For simple food queries
    "find_and_navigate_agent": find_and_navigate_agent, # Sequential
    "iterative_planner_agent": iterative_planner_agent, # Loop
    "parallel_planner_agent": parallel_planner_agent,   # Parallel
}

# --- Let's Test Everything! ---

async def run_fully_loaded_app():
    queries = [
        # Test Case 1: Simple Sequential Flow
        "Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.",

        # # Test Case 2: Iterative Loop Flow
        # "Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.",

        # Test Case 3: Parallel Flow
        "Help me plan a trip to SF. I need one museum, one concert, and one great restaurant."
    ]

    for query in queries:
        print(f"\n{'='*60}\n🗣️ Processing New Query: '{query}'\n{'='*60}")

        # 1. Ask the Router Agent to choose the right agent or workflow
        router_session = await session_service.create_session(app_name=router_agent.name, user_id=my_user_id)
        print("🧠 Asking the router agent to make a decision...")
        chosen_route = await run_agent_query(router_agent, query, router_session, my_user_id, is_router=True)
        chosen_route = chosen_route.strip().replace("'", "")
        print(f"🚦 Router has selected route: '{chosen_route}'")

        # 2. Execute the chosen route
        if chosen_route in worker_agents:
            worker_agent = worker_agents[chosen_route]
            print(f"--- Handing off to {worker_agent.name} ---")
            worker_session = await session_service.create_session(app_name=worker_agent.name, user_id=my_user_id)
            await run_agent_query(worker_agent, query, worker_session, my_user_id)
            print(f"--- {worker_agent.name} Complete ---")
        else:
            print(f"🚨 Error: Router chose an unknown route: '{chosen_route}'")

await run_fully_loaded_app()
# Out:
# ============================================================
# 🗣️ Processing New Query: 'Find me the best sushi in Palo Alto and then tell me how to get there from the Caltrain station.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '4d280dec-c276-454e-98f9-005c30496413'...
# 🚦 Router has selected route: 'find_and_navigate_agent'
# --- Handing off to find_and_navigate_agent ---
#
# 🚀 Running query for agent: 'find_and_navigate_agent' in session: 'c05c1dd2-5f90-4cc8-b380-1694c1a06433'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Kanpai Sushi'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHA_AqtZojdJpNrt6N4xy_oyc4yYwfejF8GGCNdUxfpGoGsfP6iGYbRCrPODnpcsaWlZf4q7OaIjf0noW2V1QEMW3bNzUYxx2TELSzGUnGfdxeOzbYRmf8i9VMgDJfZUdnyYwfY1JW9aHwUsx9_0sFeNVp3kbtpsKf9qST14k9Z1dHhxfFbBNdqBKPQpV7Y0hJobSdQKhLDHOE=">best sushi in Palo Alto</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEAFzYJb9D6sRnflu3Yhy8WABNlILpUlWbEInlZK7K3AYIS3-eBm2bFgQCZBWCHVTLHzTlLx_uHBVENuJu2LcYgeymxj0U8t3tin1NDGkH5E5CACqWvxn_6WQTH76KIGUn2RrUjuiQD_FvfUg7KebHHzkGmtKDJTlsf7OE5eDFgzqiqhpsKbTDRpb8sM-0D9CNeVqV37SKlkjNMMHtNPI6BVOvbM2HwEHElrA==">best sushi restaurants Palo Alto reviews</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best sushi in Palo Alto',
#     'best sushi restaurants Palo Alto reviews',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=3,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=3
#     ),
#   ],
#   prompt_token_count=108,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=108
#     ),
#   ],
#   thoughts_token_count=618,
#   tool_use_prompt_token_count=56,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=56
#     ),
#   ],
#   total_token_count=785,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-72c65a47-5311-4ad2-a94e-c51ebcce094a' author='foodie_agent' actions=EventActions(skip_summarization=None, state_delta={'destination': 'Kanpai Sushi'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='fa0df92d-ffdb-4ab8-8a6e-5fa9899e362d' timestamp=1778578992.709953
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Here's how to get to Kanpai Sushi from the Caltrain station in Palo Alto:
#
# Kanpai Sushi is located at 330 Lytton Avenue, Palo Alto, CA 94301. The Palo Alto Caltrain Station is located at 95 University Avenue, Palo Alto, CA.
#
# **Directions from Palo Alto Caltrain Station to Kanpai Sushi:**
#
# 1.  Exit the Caltrain station and head northeast on University Avenue toward Waverley Street.
# 2.  Turn left onto Waverley Street.
# 3.  Turn right onto Lytton Avenue.
# 4.  Kanpai Sushi will be on your right at 330 Lytton Avenue."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='kanpaipaloalto.com',
#         title='kanpaipaloalto.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGaTZwDbsdGqto_uSS7-C7qphLTHBTqofxJQSTrFSzMhCuJhgHpg3zk6sXx3nVi37bNhF5Y9Cl-y39aOzU_25adh05R1bAch3ZEIcN7aD7Kw5etyflV'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='wanderlog.com',
#         title='wanderlog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGOL44FKB5P_f0ZUYoZJCtBM8hrMMXp6nEzcEPbUrlyGOV0s8lZ_GwIKnohO7QOK5pJ7AKQFhqu8TBVhhxR0hoxfx2yBqpl8n1jVUP0v_MNdxLVfqXyCsMIqPiJ38fsCwwFYOA5PWo4uUxuRaI='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='restaurants-world.net',
#         title='restaurants-world.net',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHE1Uq8nKX7lo2RH0lfEQNM-fDEtEeZHcyuzc0mI8BVFYOazqLnkwNBQNVzps73GxGDrCLk_zNZt08G2sF_5OzKvvQ510OUSa_5LVSdgbpOXw7lTxmYeWYB5IMfD43A8TcsqXyCwMhJIMY='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='doordash.com',
#         title='doordash.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGnpqPqcgU20DyVKOTWYWrX83Zy8bzNEgkQxBsxmKG1WdydapCBzXUnjKZP9io_82sFDyYZoMjLQ5dLHuTXUNdZ1SrXSxefelY2YkBMhXye1Dv1ACyVavMCpK93lvaT8tSTwTCkRevAjZXpcCbr6-HPYtr9MfXZPg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='waze.com',
#         title='waze.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEluG62QGfk39ctSlK7U6Df8MTS-lGbQFq1vSKA2OMebOOHiatJdD1AElEckx4SABKIcIFCllF9CeNJuUhpYj7jkUpTQl7A0TTqDAOZIxdwx9o7RSqNyD0ublsYB3OKajO_JlBnyT9SBS0BQq0M7cTJ-c7LPfD7pgOYtxHN-cy4a1XfNJJX4N9N1xGc3lJzl0EFNKnwAeeZ6bDRhsTXQCkIKh6MfqcdP08wUDxdvdULoLk5'
#       )
#     ),
#     <... 1 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#       ],
#       segment=Segment(
#         end_index=140,
#         start_index=75,
#         text='Kanpai Sushi is located at 330 Lytton Avenue, Palo Alto, CA 94301'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=222,
#         start_index=142,
#         text='The Palo Alto Caltrain Station is located at 95 University Avenue, Palo Alto, CA'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHpaY3CH7pCt-wOWsX5Zmp4nVo4YZOZXARfnt4lI6JQunhhmGqDcafLL7OcrG46bkfwyA4MRbeefyQ8S5ZmjYWJ6VRKJeWlLDTwG8PCM5gUZv54vpdjS_Gk8H0QTYc3B20SSyyZmWlZ27FOojKEEQLickkNRp0RE0r8PwXSpT8HPPVzyM7priqmXBNFqub5-xnI_C7sNteMoOCtZfZht8hWZHvyew==">Palo Alto Caltrain station address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFYqDpphwVy0BQzLNgUagyfCX0BwB3xSX0InRMzlVvkUYd2YYXvtWLYM1-_Dc1qLfhGyB41iQaCsZ_jF83FL7WdyKrZ4avXYOOiD6cFLcQVTTh2prSCEn2In5THickApFLM1eRySi8wAmxTjaQXhp2X3pkJTqkGaSBWe6gd7lDk-VR5pbwdYCrBEvTXfN7ho7Yn442d7M6kPEzDlNXeeM3U">Kanpai Sushi Palo Alto address</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEU7_4ewsmuuAC47RMx97DwmPLPKROoGx-5AZnJcOMimjHZLDCRV2imZdSNfw8w9FdNNnhixte0pL2qlyMoazH2OPFFbH1pB47imXMrYS1Otf6nEFWBG5kGR5f_hM-tUBFY-uZO4IIKxlVc6a6E_75yz_Qt-LREkXG3qh_54cVvrPvozKItRgh93JipTpg176C48Q0s9ATXfRq19CJoiIkxqziofsOBFlrr3xuXSOrktdAkyiWGpwmer97G-4U=">directions from Palo Alto Caltrain station to Kanpai Sushi</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'Kanpai Sushi Palo Alto address',
#     'Palo Alto Caltrain station address',
#     'directions from Palo Alto Caltrain station to Kanpai Sushi',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=145,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=145
#     ),
#   ],
#   prompt_token_count=113,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=113
#     ),
#   ],
#   thoughts_token_count=155,
#   tool_use_prompt_token_count=54,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=54
#     ),
#   ],
#   total_token_count=467,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-72c65a47-5311-4ad2-a94e-c51ebcce094a' author='transportation_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='17940a7f-9455-40b3-96cc-621209f282ba' timestamp=1778579013.395404
#
# --------------------------------------------------
# ✅ Final Response:
# Here's how to get to Kanpai Sushi from the Caltrain station in Palo Alto:
#
# Kanpai Sushi is located at 330 Lytton Avenue, Palo Alto, CA 94301. The Palo Alto Caltrain Station is located at 95 University Avenue, Palo Alto, CA.
#
# **Directions from Palo Alto Caltrain Station to Kanpai Sushi:**
#
# 1.  Exit the Caltrain station and head northeast on University Avenue toward Waverley Street.
# 2.  Turn left onto Waverley Street.
# 3.  Turn right onto Lytton Avenue.
# 4.  Kanpai Sushi will be on your right at 330 Lytton Avenue.
# --------------------------------------------------
#
# --- find_and_navigate_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Plan me a day in San Francisco with a museum and a nice dinner, but make sure the travel time between them is very short.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: 'd4a9a91e-7dc8-4e52-83fa-b31a67136474'...
# 🚦 Router has selected route: 'iterative_planner_agent'
# --- Handing off to iterative_planner_agent ---
#
# 🚀 Running query for agent: 'iterative_planner_agent' in session: '39264801-1842-4585-80dc-54d45f21d88c'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Activity: San Francisco Museum of Modern Art (SFMOMA)
# Restaurant: In Situ"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQ
#
# --------------------------------------------------
# ✅ Final Response:
# An error occurred: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'Multiple tools are supported only when they are all search tools.', 'status': 'INVALID_ARGUMENT'}}
# --------------------------------------------------
#
# --- iterative_planner_agent Complete ---
#
# ============================================================
# 🗣️ Processing New Query: 'Help me plan a trip to SF. I need one museum, one concert, and one great restaurant.'
# ============================================================
# 🧠 Asking the router agent to make a decision...
#
# 🚀 Running query for agent: 'router_agent' in session: '576bb503-3b7f-460b-80b1-0a071eeb1e69'...
# 🚦 Router has selected route: 'parallel_planner_agent'
# --- Handing off to parallel_planner_agent ---
#
# 🚀 Running query for agent: 'parallel_planner_agent' in session: '315d02e4-6d91-4252-a9d4-36afd1a882b1'...
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='Exploratorium'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='gocity.com',
#         title='gocity.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFBRnLHP2qoYDXlKQkuPYVUjeSO7SwYJjsrXQW0ujwNOTVCDWkf7G6O0AUzDxeoIAZZTe-QHTn1DkIVPhyQv9pvlMkv4J6wZNvU0kJ1b9-g31IFobThC-cZEJPwt00Vqz4Dzt9BzLrJHX-qvhjOX-9jvNXXi3nz3lKtJat-aoOaBMQIBDzwi8Z0hg=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='exploratorium.edu',
#         title='exploratorium.edu',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEdbOoxEWVnmfjoX5YOmSDBuN_AlvH5EBgAbDI1IYqVsF2IgLImHhYBAuWdGdJZi4rkLG8nLg_p3eqJWbnYQK0lb36koRV0OFnNIrJ03BpDPdWErGenMYINgw=='
#       )
#     ),
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=13,
#         text='Exploratorium'
#       )
#     ),
#   ],
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGUM8RtgZkBQH90NEdq5Aoddy5OnWh0rqXqMZA_V2Gtn_NyNP16oa8CStaFHfNz_78g2wBunz6SuGxge5jyAEeHL14yckQpoRH1Zpk1SIl4X7H6Ndtif2LXnnsaZvUvXCxraMAzLY7QS_w3kEnoblzUdlkSSdMycHBRqAqxw9AcZGGRDsSsztbPYSrE8kuO9NfipKcvuOxCLA-MgovSfPky0wk=">top-rated museums San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGF22edKpOh1vLPmPMq7iiGODLcJ1zFt6PpAPpZsc_jwwlXOpROeWWaZrrpuVB930RSYT1ScIGzwFkLSi6v6RYLfq2vIR_QppjGc1xnXJJwYzUuMMMHQgrXueVsBaQs-G9NpzzKHyBIWOIkc4vgLEpdbWRhk60G-K2iDnCKKtYPFjHB6gi82daXmKVfB1j7oxLKkGU-mLo47jz7oeOADm2V">best museums in San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE72_brA7B8Rr-ffGKuXZkMgsyqaz1OaGR3wwGdRBPNIRjUaIzcV1MyVffd3rPu9xRCgGlQCOuQ8W5PWNP1RUom2La_IiH1uUPKyE91yLmgxsDFGLdOHHtCAWvqK__7w2wg7aJe-aINjb9qghcrsF5mMIlUNLMTUcoJiLIDo3pX6qcd8u0gRCzkvPr33xvzDQ6MqJmdJA==">popular museums SF</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best museums in San Francisco',
#     'top-rated museums San Francisco',
#     'popular museums SF',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=3,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=3
#     ),
#   ],
#   prompt_token_count=64,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=64
#     ),
#   ],
#   thoughts_token_count=651,
#   tool_use_prompt_token_count=224,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=224
#     ),
#   ],
#   total_token_count=942,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-37b17741-e921-4402-af8c-5b8586f81198' author='museum_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'museum_result': 'Exploratorium'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch='parallel_research_agent.museum_finder_agent' id='e0edd180-98bc-42a9-b5f3-a90ae7c06271' timestamp=1778579075.5618155
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Here's a possible itinerary for your trip to San Francisco:
#
# **Concert:**
# The Freedom Tour - Kesha
#
# **Museum:**
# For a museum, I recommend the **Exploratorium**. It's a highly interactive and hands-on museum focusing on science and human perception, beloved by both locals and visitors of all ages. You can explore hundreds of exhibits across its six indoor and outdoor galleries at Pier 15.
#
# **Restaurant:**
# For a great restaurant, consider **Waterbar**. Situated on San Francisco's Embarcadero waterfront, it offers fresh-caught, sustainably sourced seafood and an expansive selection of oysters, all with panoramic views of the Bay Bridge lights, Treasure Island, and the San Francisco skyline."""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='san-francisco-theater.com',
#         title='san-francisco-theater.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEKy3Ri7xMIQjNMV6MJ9FaTN1MucIgQzGy7mj45mbhBf-sOdsYmW1FbJ-iwh6dEo9khN2-P1Ft0sXA23wce--CzdGAQYM82TNAGh5FZFFawnKMs-6FjC_KY2QmwN9VRyxOAiJ10FLHDnEz4n_Gbdpb3hUBT2deRr2h-dJWlLD8A'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='sftourismtips.com',
#         title='sftourismtips.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGtJgyeR1vSEq7qCIglrrAQnGCg7gAXaneTRP68ckLwWMLazooRsw_s2S_89pmNWxMNNS9l6db0AxQKRdMxolUUTkxeM8wnJT5p5pvDTCWaHc_IC4CUjWcicgkG2C5Nb3s2WGnOOzqkn7t6X17Rt48Wxh2J'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         domain='exploratorium.edu',
#         title='exploratorium.edu',
# ...
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEnP0gUlIbcPx8u8J4yvO7yVK66a8Hu4NumtHdz8K0QKgrZ2MNRNW2XrJeYX7ZdFr7_cYiUBfKQOxdtwjtp_D7E9Kly-PAb910lT0HUZrvh9HChEbdYGRRQ8ST1uVxuPVZh24W98vXZmJWTDNSOorx2WgWsi7nITgwcOGpyd4Nr975thkBk5KdHuTo_3V4IUgD6SHEHvrc129JPLlyKLTBU0A==">best restaurants San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGorwJ1sVCcpng2e88o1donillpMHRqL__5EIEECl88k7j68oLLg0CQfsV0ZNF7DwAOD0qb1I81EI5C9_cvyv9YgghVDEhNt1SLxq6PtJViUxet0Pon_sjtfd4HHSUza_Wqmt_t1QA6xQS_YUFy_2bat_axh7sB0bcfcuaprDKnRYN3Xdr2Mlxb7QwecM9HkYmeURYa9CXtf7kkFlCsZBjFUw4=">concerts San Francisco May 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFiIm6kX3ZpVxEeNBzfGr4sIhAmvwIxaldPCovSIqFmkqrI4g-Yd4cWvlvslC2JAzjYx8flqlLUdutcOW6QaNXoflnkbAu5cziFepPtYbqkOFWDWQ0OGoIK4m5DVHz270OoWNrugz_yq8DhhmKBujDWwZtEFSFHBLHFPuTJVczSjzsZdyuqHAkYOsZzkeh7e_Xburxs5M5f2Q==">San Francisco museums</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'concerts San Francisco May 2026',
#     'San Francisco museums',
#     'best restaurants San Francisco',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=150,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=150
#     ),
#   ],
#   prompt_token_count=63,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=63
#     ),
#   ],
#   thoughts_token_count=788,
#   tool_use_prompt_token_count=217,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=217
#     ),
#   ],
#   total_token_count=1218,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-37b17741-e921-4402-af8c-5b8586f81198' author='concert_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'concert_result': "Here's a possible itinerary for your trip to San Francisco:\n\n**Concert:**\nThe Freedom Tour - Kesha\n\n**Museum:**\nFor a museum, I recommend the **Exploratorium**. It's a highly interactive and hands-on museum focusing on science and human perception, beloved by both locals and visitors of all ages. You can explore hundreds of exhibits across its six indoor and outdoor galleries at Pier 15.\n\n**Restaurant:**\nFor a great restaurant, consider **Waterbar**. Situated on San Francisco's Embarcadero waterfront, it offers fresh-caught, sustainably sourced seafood and an expansive selection of oysters, all with panoramic views of the Bay Bridge lights, Treasure Island, and the San Francisco skyline."}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch='parallel_research_agent.concert_finder_agent' id='a4f27738-ee01-4539-ade5-b295b04b2879' timestamp=1778579075.7512465
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text='7 Adams'
#     ),
#   ],
#   role='model'
# ) grounding_metadata=GroundingMetadata(
#   retrieval_metadata=RetrievalMetadata(),
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #fafafa 15%, #fafafa00 100%);
#   }
# }
# @media (prefers-color-scheme: dark) {
#   .container {
#     background-color: #1f1f1f;
#     box-shadow: 0 0 0 1px #ffffff26;
#   }
#   .headline-label {
#     color: #fff;
#   }
#   .chip {
#     background-color: #2c2c2c;
#     border-color: #3c4043;
#     color: #fff;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #353536;
#   }
#   .chip:focus {
#     background-color: #353536;
#   }
#   .chip:active {
#     background-color: #464849;
#     border-color: #53575b;
#   }
#   .logo-light {
#     display: none;
#   }
#   .gradient {
#     background: linear-gradient(90deg, #1f1f1f 15%, #1f1f1f00 100%);
#   }
# }
# </style>
# <div class="container">
#   <div class="headline">
#     <svg class="logo-light" width="18" height="18" viewBox="9 9 35 35" fill="none" xmlns="http://www.w3.org/2000/svg">
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M42.8622 27.0064C42.8622 25.7839 42.7525 24.6084 42.5487 23.4799H26.3109V30.1568H35.5897C35.1821 32.3041 33.9596 34.1222 32.1258 35.3448V39.6864H37.7213C40.9814 36.677 42.8622 32.2571 42.8622 27.0064V27.0064Z" fill="#4285F4"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 43.8555C30.9659 43.8555 34.8687 42.3195 37.7213 39.6863L32.1258 35.3447C30.5898 36.3792 28.6306 37.0061 26.3109 37.0061C21.8282 37.0061 18.0195 33.9811 16.6559 29.906H10.9194V34.3573C13.7563 39.9841 19.5712 43.8555 26.3109 43.8555V43.8555Z" fill="#34A853"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M16.6559 29.8904C16.3111 28.8559 16.1074 27.7588 16.1074 26.6146C16.1074 25.4704 16.3111 24.3733 16.6559 23.3388V18.8875H10.9194C9.74388 21.2072 9.06992 23.8247 9.06992 26.6146C9.06992 29.4045 9.74388 32.022 10.9194 34.3417L15.3864 30.8621L16.6559 29.8904V29.8904Z" fill="#FBBC05"/>
#       <path fill-rule="evenodd" clip-rule="evenodd" d="M26.3109 16.2386C28.85 16.2386 31.107 17.1164 32.9095 18.8091L37.8466 13.8719C34.853 11.082 30.9659 9.3736 26.3109 9.3736C19.5712 9.3736 13.7563 13.245 10.9194 18.8875L16.6559 23.3388C18.0195 19.2636 21.8282 16.2386 26.3109 16.2386V16.2386Z" fill="#EA4335"/>
#     </svg>
#     <svg class="logo-dark" width="18" height="18" viewBox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#       <circle cx="24" cy="23" fill="#FFF" r="22"/>
#       <path d="M33.76 34.26c2.75-2.56 4.49-6.37 4.49-11.26 0-.89-.08-1.84-.29-3H24.01v5.99h8.03c-.4 2.02-1.5 3.56-3.07 4.56v.75l3.91 2.97h.88z" fill="#4285F4"/>
#       <path d="M15.58 25.77A8.845 8.845 0 0 0 24 31.86c1.92 0 3.62-.46 4.97-1.31l4.79 3.71C31.14 36.7 27.65 38 24 38c-5.93 0-11.01-3.4-13.45-8.36l.17-1.01 4.06-2.85h.8z" fill="#34A853"/>
#       <path d="M15.59 20.21a8.864 8.864 0 0 0 0 5.58l-5.03 3.86c-.98-2-1.53-4.25-1.53-6.64 0-2.39.55-4.64 1.53-6.64l1-.22 3.81 2.98.22 1.08z" fill="#FBBC05"/>
#       <path d="M24 14.14c2.11 0 4.02.75 5.52 1.98l4.36-4.36C31.22 9.43 27.81 8 24 8c-5.93 0-11.01 3.4-13.45 8.36l5.03 3.85A8.86 8.86 0 0 1 24 14.14z" fill="#EA4335"/>
#     </svg>
#     <div class="gradient-container"><div class="gradient"></div></div>
#   </div>
#   <div class="carousel">
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEsieQ97Bl9QipkvCVATznpexg5OL-9_FXR_fGvqcrIx1Do_QMMogdMs-F5mhiG1Q-N7XiAhc5BjVd6hGISyS3wHJR4V-zDJDSlRihQJISlJAfwkM61P0KDda0eW6cVmi-e6Aq1dftluLtwfw7XmukkOmnMigEkQAYDHXAqsYUnEnwVyKEYzGpydWXJoahguRXtQ8Dqgz3-cN2UKtPhEAivMyfKm6_eoTY=">San Francisco concert venues May 2026</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFZh60sIzEOZmhszK60HUfnQEkL0U3LcHnpNtrb9o0ciVrP9ACry437z4mjmX_QMY4C1B31AN_6pw_C7S2TU2WnWaotbT8Ms0PqlAF7qWpDtqd0l3rgYbUpgnjpg1OSJrOD-opoCoEu0JNbNh2TuuJMqnNONbyzYHV8ygem9UHp-eobUUC-M1-mjsa5QoQtsGiRcetAg8sTqzYhy6FI">best museums San Francisco</a>
#     <a class="chip" href="https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHWj5rVUFsrOql-JKVZLpDO02nqwqpp13VBOEHRnQjH03rF4lz1bo8RFPw29YDvTdljWcYRKb1ub13F331dcOT1TTLV-R5WK9lq22CqumHUvoddUTL0vTaGvaHGgHR-o8pcaRiaHejfiz63Ln0uWvQ1dpknPJD8aUz8abkhnCpmhgEGZxik1bC0TKcpcJMg-Tv_-uMWy4tBU_rro8VYxAYKIg==">best restaurants San Francisco</a>
#   </div>
# </div>
# """
#   ),
#   web_search_queries=[
#     'best museums San Francisco',
#     'San Francisco concert venues May 2026',
#     'best restaurants San Francisco',
#   ]
# ) partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2
#     ),
#   ],
#   prompt_token_count=105,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=105
#     ),
#   ],
#   thoughts_token_count=1027,
#   tool_use_prompt_token_count=148,
#   tool_use_prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=148
#     ),
#   ],
#   total_token_count=1282,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-37b17741-e921-4402-af8c-5b8586f81198' author='restaurant_finder_agent' actions=EventActions(skip_summarization=None, state_delta={'restaurant_result': '7 Adams'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch='parallel_research_agent.restaurant_finder_agent' id='0a7ef6e8-d290-40d3-92f8-7a7bc3d710df' timestamp=1778579075.9439154
# EVENT: model_version='gemini-2.5-flash' content=Content(
#   parts=[
#     Part(
#       text="""Here are some recommendations for your trip to San Francisco:
#
# *   **Museum:** Exploratorium
# *   **Concert:** The Freedom Tour - Kesha
# *   **Restaurant:**
#     *   Waterbar
#     *   7 Adams"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=<FinishReason.STOP: 'STOP'> error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=50,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=50
#     ),
#   ],
#   prompt_token_count=422,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=422
#     ),
#   ],
#   thoughts_token_count=887,
#   total_token_count=1359,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ) live_session_resumption_update=None go_away=None input_transcription=None output_transcription=None avg_logprobs=-7.19347900390625 logprobs_result=None cache_metadata=None citation_metadata=None interaction_id=None invocation_id='e-37b17741-e921-4402-af8c-5b8586f81198' author='synthesis_agent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None, render_ui_widgets=None) long_running_tool_ids=None branch=None id='132a85a6-2adc-4828-be33-ec5bbfbf908b' timestamp=1778579093.7539144
#
# --------------------------------------------------
# ✅ Final Response:
# Here are some recommendations for your trip to San Francisco:
#
# *   **Museum:** Exploratorium
# *   **Concert:** The Freedom Tour - Kesha
# *   **Restaurant:**
#     *   Waterbar
#     *   7 Adams
# --------------------------------------------------
#
# --- parallel_planner_agent Complete ---

# %% [markdown]
# ---
# ## 🎉 Congratulations! 🎉
#
# You've completed the Enhanced ADK Adventure! You have successfully. Let's review the advanced orchestration patterns you've successfully implemented:
#
# - **The Router Pattern**: You built a master router agent capable of analyzing user intent and delegating tasks to the appropriate specialist agent or workflow.
#
# - **Sequential Workflows**: Using SequentialAgent, you elegantly chained agents together, creating clean, readable code for multi-step tasks without manual data handling.
#
# - **Iterative Refinement**: You constructed a sophisticated feedback loop with LoopAgent, enabling your agents to plan, self-critique, and improve their output until it met specific constraints.
#
# - **Parallel Power**: You maximized speed and efficiency by using ParallelAgent to run multiple research tasks concurrently, later synthesizing the results into a unified response.

# %% [markdown]
# ```
#    __            /\_/\         /\_/\        /\_/\         __             (\__/)
# o-''|\_____/).  ( o.o )       ( -.- )      ( ^_^ )     o-''|\_____/).    ( ^_^ )
#  \_/|_)     )    > ^ <         > * <        >💖<         \_/|_)     )     / >🌸< \
#     \  __  /                                              \  __  /         /   \
#     (_/ (_/                                               (_/ (_/        (___|___)
# ```
